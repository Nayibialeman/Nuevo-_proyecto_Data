# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import os
archivo = open('Emisiones_CO2.csv', 'r', encoding='latin-1')

# %%
#Abrir el archivo y leer linea por linea
#uso utf-8 para que no halla problemas al leer acentos etc
#next se usa para omitir el ENCABEZADO del archivo y comenzar a leer desde la linea 2

#split separa una cadena con el separador (',') y la convierte a arreglo
#declaro el diccionario donde van a estar todas las columnas de mi archivo "dicc_emisiones"
import os
archivo = open('Emisiones_CO2.csv', 'r', encoding='latin-1')  
next(archivo) 
datos= ""
datos = datos.rstrip("\n") #quitar el salto de linea para tener linea limpia  
columnas = datos.split(',') #despues de eso, ya se tendrá todo separado por ","
dicc_emisiones = {  'cod_pais' : [],
                            'nom_pais' : [],
                            'region' : [],
                            'anio' : [],
                            'co2' : [],
                            'co2_percapita' : []}
for datos in archivo: #El archivo será recorrido o iterado y va a "desempacar los valores, agregandolos con append"
            dicc_emisiones["cod_pais"].append(lista_datos[0])
            dicc_emisiones["nom_pais"].append(lista_datos[1])
            dicc_emisiones["region"].append(lista_datos[2])
            dicc_emisiones["anio"].append(lista_datos[3])
            dicc_emisiones["co2"].append(lista_datos[4])
            dicc_emisiones["co2_percapita"].append(lista_datos[5])


#e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?
region = "América Latina y Caribe"
año = "2010"

region = "América Latina y Caribe"
año = "2010"

if [i for i, (x, y) in enumerate(zip(dicc_emisiones["region"], dicc_emisiones["anio"])) if x == region and y == año]:
    print(f"El total de emisiones de CO2 para {region} en el año {año} fue de ", dicc_emisiones["co2"][matching_indices[0]])
print(dicc_emisiones['co2'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# f:\Data Science\Nueva carpeta (2)\Clase 02\Homework 2 M1.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/f%3A/Data%20Science/Nueva%20carpeta%20%282%29/Clase%2002/Homework%202%20M1.ipynb#X21sZmlsZQ%3D%3D?line=20'>21</a> dicc_emisiones["nom_pais"].append(lista_datos[1])
#      <a href='vscode-notebook-cell:/f%3A/Data%20Science/Nueva%20carpeta%20%282%29/Clase%2002/Homework%202%20M1.ipynb#X21sZmlsZQ%3D%3D?line=21'>22</a> dicc_emisiones["region"].append(lista_datos[2])
# ---> <a href='vscode-notebook-cell:/f%3A/Data%20Science/Nueva%20carpeta%20%282%29/Clase%2002/Homework%202%20M1.ipynb#X21sZmlsZQ%3D%3D?line=22'>23</a> dicc_emisiones["anio"].append(lista_datos[3])
# ...

# %%
def process_emissions_data():
    archivo = open('Emisiones_CO2.csv', 'r', encoding='latin-1')  
    next(archivo)
    dicc_emisiones = {
            'cod_pais': [],
            'nom_pais': [],
            'region': [],
            'anio': [],
            'co2': [],
            'co2_percapita': []
        }

    for linea in archivo:
            datos = linea.rstrip("\n")
            lista_datos = datos.split(',')
            dicc_emisiones["cod_pais"].append(lista_datos[0])
            dicc_emisiones["nom_pais"].append(lista_datos[1])
            dicc_emisiones["region"].append(lista_datos[2])
            dicc_emisiones["anio"].append(lista_datos[3])
            dicc_emisiones["co2"].append(lista_datos[4])
            dicc_emisiones["co2_percapita"].append(lista_datos[5])

region = "América Latina y Caribe"
año = "2010"

if [i for i, (x, y) in enumerate(zip(dicc_emisiones["region"], dicc_emisiones["anio"])) if x == region and y == año]:
    print(f"El total de emisiones de CO2 para {region} en el año {año} fue de ", dicc_emisiones["co2"][matching_indices[0]])
print(dicc_emisiones['co2'])
# Out:
# []

# %%
def process_emissions_data():
    archivo = open('Emisiones_CO2.csv', 'r', encoding='latin-1')  
    next(archivo)
    dicc_emisiones = {
            'cod_pais': [],
            'nom_pais': [],
            'region': [],
            'anio': [],
            'co2': [],
            'co2_percapita': []
        }

    for linea in archivo:
            datos = linea.rstrip("\n")
            lista_datos = datos.split(',')
            dicc_emisiones["cod_pais"].append(lista_datos[0])
            dicc_emisiones["nom_pais"].append(lista_datos[1])
            dicc_emisiones["region"].append(lista_datos[2])
            dicc_emisiones["anio"].append(lista_datos[3])
            dicc_emisiones["co2"].append(lista_datos[4])
            dicc_emisiones["co2_percapita"].append(lista_datos[5])

region = "América Latina y Caribe"
año = "2010"

for i, x in enumerate(dicc_emisiones["region"]):
    if x == region and dicc_emisiones["anio"][i] == año:
        print(f"El total de emisiones de CO2 para {region} en el año {año} fue de ", dicc_emisiones["co2"][i])
        break

# %%
# encontrar el total CO2 por año y region
region = "América Latina y Caribe"
año = "2010"
for i, x in enumerate(dicc_emisiones["region"]):
    if x == region and dicc_emisiones["anio"][i] == año:
        print(f"El total de emisiones de CO2 para {region} en el año {año} fue de ", dicc_emisiones["co2"][i])
        break

# %%
for i, x in enumerate(dicc_emisiones["region"]):
    if x == region and dicc_emisiones["anio"][i] == año:
        print(f"El total de emisiones de CO2 para {region} en el año {año} fue de ", dicc_emisiones["co2"][i])
        break

# %%
# Call the function
process_emissions_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\Data Science\Nueva carpeta (2)\Clase 02\Homework 2 M1.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/f%3A/Data%20Science/Nueva%20carpeta%20%282%29/Clase%2002/Homework%202%20M1.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # Call the function
# ----> <a href='vscode-notebook-cell:/f%3A/Data%20Science/Nueva%20carpeta%20%282%29/Clase%2002/Homework%202%20M1.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> process_emissions_data('América Latina y Caribe', '2010')
#
# TypeError: process_emissions_data() takes 0 positional arguments but 2 were given

# %%
# Usage
file_path = 'Emisiones_CO2.csv'
data_dictionary = process_emissions_data(file_path)
# Out:
# []

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?
